# %%
from PIL import Image
imgpath='../data/dem/ALPSMLC30_N040E120_DSM.tif'
img=Image.open(imgpath)
print('%s, %s, %s' % (img.mode, img.size, img.format))
img.show()
# Out:
# I, (3600, 3600), TIFF
# <PIL.Image.Image image mode=L size=3600x3600>
